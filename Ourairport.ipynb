# %%
import pandas as pd

# %%
df = pd.read_csv("airports.csv")

# %%
df.head()
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total RF Heliport     40.070985
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933689          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service icao_code iata_code gps_code local_code  \
# ...

# %%
df_europe = df[df['continent'] == "EU"]

# %%
df_europe.head()
# Out:
#           id    ident      type  \
# 9335  318235  AD-0001  heliport
# 9336  338490  AD-0002    closed
# 9337   41841   AD-ALV  heliport
# 9568  300646      AEI  heliport
# 9744   35356  AL-0001  heliport
#
#                                                    name  latitude_deg  \
# 9335                          Terra Guindaldes Heliport     42.546257
# 9336              Arinsal (Coll de la Botella) Heliport     42.544983
# 9337  Andorra la Vella (Our Lady of Meritxell Hospit...     42.511228
# 9568                                 Algeciras Heliport     36.128820
# 9744                                   Lapraka Heliport     41.330782
#
#       longitude_deg  elevation_ft continent iso_country iso_region  \
# 9335       1.519160           NaN        EU          AD      AD-04
# 9336       1.452258           NaN        EU          AD      AD-04
# 9337       1.533651        3450.0        EU          AD      AD-08
# 9568      -5.441079          98.0        EU          ES      ES-AN
# ...

# %%
df_europe.describe
# Out:
# <bound method NDFrame.describe of            id    ident           type  \
# 9568   300646      AEI       heliport
# 10792   43818  AT-0001       heliport
# 10793   46529  AT-0002  seaplane_base
# 10794  312150  AT-0003       heliport
# 10795  312153  AT-0004       heliport
# ...       ...      ...            ...
# 77882  512355     VB02  small_airport
# 78345  333095      VIF       heliport
# 82038  300640  ZA-0102         closed
# 82706   46378  ZZ-0001       heliport
# 82709  595235  ZZ-0004       heliport
#
#                                                 name  latitude_deg  \
# 9568                              Algeciras Heliport     36.128820
# 10792                        Pöchlarn-Wörth Heliport     48.214737
# 10793       Scalaria Airchallenge Water Landing Area     47.734705
# 10794         Bad Tatzmannsdorf PVA Hospital Helipad     47.330720
# 10795                       Güssing Hospital Helipad     47.049770
# ...

# %%
european_countries = ["FR", "DE", "IT", "ES", "GB", "NL", "PL", "SE", "CH", "BE", "AT", "NO", "DK", "FI", "PT", "IE", "GR"]  # Add more as needed
df_europe = df[df["iso_country"].isin(european_countries)]

# %%
df_europe.head()
# Out:
#            id    ident           type  \
# 9568   300646      AEI       heliport
# 10792   43818  AT-0001       heliport
# 10793   46529  AT-0002  seaplane_base
# 10794  312150  AT-0003       heliport
# 10795  312153  AT-0004       heliport
#
#                                            name  latitude_deg  longitude_deg  \
# 9568                         Algeciras Heliport     36.128820      -5.441079
# 10792                   Pöchlarn-Wörth Heliport     48.214737      15.255424
# 10793  Scalaria Airchallenge Water Landing Area     47.734705      13.443832
# 10794    Bad Tatzmannsdorf PVA Hospital Helipad     47.330720      16.222070
# 10795                  Güssing Hospital Helipad     47.049770      16.321700
#
#        elevation_ft continent iso_country iso_region       municipality  \
# 9568           98.0        EU          ES      ES-AN          Algeciras
# 10792         709.0        EU          AT       AT-3     Pöchlarn-Wörth
# ...

# %%
df_europe.describe
# Out:
# <bound method NDFrame.describe of            id    ident           type  \
# 9568   300646      AEI       heliport
# 10792   43818  AT-0001       heliport
# 10793   46529  AT-0002  seaplane_base
# 10794  312150  AT-0003       heliport
# 10795  312153  AT-0004       heliport
# ...       ...      ...            ...
# 77882  512355     VB02  small_airport
# 78345  333095      VIF       heliport
# 82038  300640  ZA-0102         closed
# 82706   46378  ZZ-0001       heliport
# 82709  595235  ZZ-0004       heliport
#
#                                                 name  latitude_deg  \
# 9568                              Algeciras Heliport     36.128820
# 10792                        Pöchlarn-Wörth Heliport     48.214737
# 10793       Scalaria Airchallenge Water Landing Area     47.734705
# 10794         Bad Tatzmannsdorf PVA Hospital Helipad     47.330720
# 10795                       Güssing Hospital Helipad     47.049770
# ...

# %%
df_europe = df_europe[["id", "name", "iso_country", "iata_code", "icao_code", "latitude_deg", "longitude_deg", "elevation_ft", "type", "municipality"]]

# %%
df_europe.shape
# Out:
# (8703, 10)
